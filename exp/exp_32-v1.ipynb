# %%
# %load_ext autoreload
# %autoreload 2
import sys
sys.path.append('..')
import os
os.environ["CUDA_VISIBLE_DEVICES"]="0"
os.environ["MKL_NUM_THREADS"] = "8" 
os.environ["NUMEXPR_NUM_THREADS"] = "8" 
os.environ["OMP_NUM_THREADS"] = "8"

# %%
import rnacomp
import rnacomp.models
from rnacomp.fastai_fit import *
from rnacomp.dataset import LenMatchBatchSampler, DeviceDataLoader
from rnacomp.utils import seed_everything, MAE, loss_laplace
import gc
import wandb 
from fastxtend.vision.all import EMACallback

# %%
class CFG:
    path = Path("../data/")
    pathbb = Path("../data/Ribonanza_bpp_files")
    pathss = Path("../eda/train_ss_vienna_rna.parquet")
    split_id = Path('../eda/fold_split.csv')
    bs = 64
    num_workers = 4
    device = 'cuda'
    seed = 2023
    out = 'exp_32_v1'
    dataset_name = 'RNA_DatasetBaselineSplitssbppV6SAVED'
    sn_train = False
    
    model_name = 'RNA_ModelV25'
    model_kwargs = dict(dim=192 * 2,
        depth=4,
        head_size=32,
        drop_pat_dropout=0.2,
        dropout=0.2,
        bpp_transfomer_depth = 4)

   
    epoch = 64
    lr = 5e-4
    wd = 0.05
    pct_start = 0.02
    
    wandb = True
    
seed_everything(CFG.seed)
os.makedirs(CFG.out, exist_ok=True)

# wandb.init(
#     # set the wandb project where this run will be logged
#     project="my-awesome-project",
    
#     # track hyperparameters and run metadata
#     config={
#     "learning_rate": 0.02,
#     "architecture": "CNN",
#     "dataset": "CIFAR-100",
#     "epochs": 10,
#     }
# )

def class_to_dict(cls):
    # Create a dictionary from the class attributes
    return {key: value for key, value in cls.__dict__.items() if not key.startswith("__") and not callable(value)}

# %%
split = pd.read_csv(CFG.split_id)
df = pd.read_parquet(CFG.path/'train_data.parquet')
df = pd.merge(df, split, on='sequence_id')
#df = df.query("SN_filter==1").reset_index(drop=True)
df_train = df.query('is_train==True').reset_index(drop=True)
df_valid = df.query('is_train==False').reset_index(drop=True)


ds_train = getattr(rnacomp.dataset, CFG.dataset_name)(df_train, mode='train',sn_train=CFG.sn_train)
ds_train_len = getattr(rnacomp.dataset, CFG.dataset_name)(df_train, mode='train', mask_only=True,sn_train=CFG.sn_train)
sampler_train = torch.utils.data.RandomSampler(ds_train_len)
len_sampler_train = LenMatchBatchSampler(sampler_train, batch_size=CFG.bs,
            drop_last=True)
dl_train = DeviceDataLoader(torch.utils.data.DataLoader(ds_train, 
            batch_sampler=len_sampler_train, num_workers=CFG.num_workers,
            persistent_workers=True), CFG.device)


ds_val = getattr(rnacomp.dataset, CFG.dataset_name)(df_valid, mode='eval')
ds_val_len = getattr(rnacomp.dataset, CFG.dataset_name)(df_valid, mode='eval', mask_only=True)
sampler_val = torch.utils.data.SequentialSampler(ds_val_len)
len_sampler_val = LenMatchBatchSampler(sampler_val, batch_size=CFG.bs, 
               drop_last=False)
dl_val= DeviceDataLoader(torch.utils.data.DataLoader(ds_val, 
               batch_sampler=len_sampler_val, num_workers=CFG.num_workers), CFG.device)

data = DataLoaders(dl_train,dl_val)
del split
del df
gc.collect()
# Out:
# 59

# %%
learn = Learner(data,
                getattr(rnacomp.models, CFG.model_name)(**CFG.model_kwargs).cuda(), 
                path = CFG.out, 
                loss_func=loss_laplace,
                cbs=[GradientClip(3.0),
                    #WandbCallback(log_preds=False),
                    CSVLogger(),
                     EMACallback(),
                    SaveModelCallback(monitor='mae',comp=np.less,at_end=True)],
                metrics=[MAE()]).to_fp16() 
learn.fit_one_cycle(CFG.epoch, lr_max=CFG.lr, wd=CFG.wd, pct_start=CFG.pct_start)
wandb.finish()
# Out:
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     progress:not([value]), progress:not([value])::-webkit-progress-bar {
#         background: repeating-linear-gradient(45deg, #7e7e7e, #7e7e7e 10px, #5c5c5c 10px, #5c5c5c 20px);
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>
#     <div>
#       <progress value='34' class='' max='64' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       53.12% [34/64 22:54:26&lt;20:12:44]
#     </div>
#
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>mae</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>0.126599</td>
#       <td>0.214973</td>
#       <td>0.168818</td>
#       <td>39:28</td>
#     </tr>
#     <tr>
#       <td>1</td>
#       <td>0.119671</td>
#       <td>0.142372</td>
#       <td>0.143254</td>
#       <td>39:49</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>0.118432</td>
#       <td>0.125562</td>
#       <td>0.135346</td>
#       <td>40:07</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>0.117458</td>
#       <td>0.123406</td>
#       <td>0.133112</td>
#       <td>40:09</td>
#     </tr>
#     <tr>
#       <td>4</td>
#       <td>0.116769</td>
#       <td>0.122218</td>
#       <td>0.131898</td>
#       <td>40:14</td>
#     </tr>
#     <tr>
#       <td>5</td>
#       <td>0.117250</td>
#       <td>0.121559</td>
#       <td>0.131234</td>
#       <td>40:13</td>
#     </tr>
#     <tr>
#       <td>6</td>
#       <td>0.115951</td>
#       <td>0.121077</td>
#       <td>0.130723</td>
#       <td>40:15</td>
#     </tr>
#     <tr>
#       <td>7</td>
#       <td>0.116014</td>
#       <td>0.120632</td>
#       <td>0.130224</td>
#       <td>40:19</td>
#     </tr>
#     <tr>
#       <td>8</td>
#       <td>0.115754</td>
#       <td>0.120309</td>
#       <td>0.129875</td>
#       <td>40:22</td>
#     </tr>
#     <tr>
#       <td>9</td>
#       <td>0.115796</td>
#       <td>0.119967</td>
#       <td>0.129487</td>
#       <td>40:21</td>
#     </tr>
#     <tr>
#       <td>10</td>
#       <td>0.113558</td>
#       <td>0.119743</td>
#       <td>0.129250</td>
#       <td>40:23</td>
#     </tr>
#     <tr>
#       <td>11</td>
#       <td>0.113418</td>
#       <td>0.119581</td>
#       <td>0.129086</td>
#       <td>40:25</td>
#     </tr>
#     <tr>
#       <td>12</td>
#       <td>0.114254</td>
#       <td>0.119301</td>
#       <td>0.128777</td>
#       <td>40:26</td>
#     </tr>
#     <tr>
#       <td>13</td>
#       <td>0.113646</td>
#       <td>0.119136</td>
#       <td>0.128590</td>
#       <td>40:26</td>
#     </tr>
#     <tr>
#       <td>14</td>
#       <td>0.114604</td>
#       <td>0.118958</td>
#       <td>0.128397</td>
#       <td>40:28</td>
#     </tr>
#     <tr>
#       <td>15</td>
#       <td>0.113432</td>
#       <td>0.118744</td>
#       <td>0.128167</td>
#       <td>40:26</td>
#     </tr>
#     <tr>
#       <td>16</td>
#       <td>0.113677</td>
#       <td>0.118605</td>
#       <td>0.128001</td>
#       <td>40:32</td>
#     </tr>
#     <tr>
#       <td>17</td>
#       <td>0.114146</td>
#       <td>0.118481</td>
#       <td>0.127846</td>
#       <td>40:28</td>
#     </tr>
#     <tr>
#       <td>18</td>
#       <td>0.114314</td>
#       <td>0.118353</td>
#       <td>0.127722</td>
#       <td>40:31</td>
#     </tr>
#     <tr>
#       <td>19</td>
#       <td>0.114956</td>
#       <td>0.118322</td>
#       <td>0.127692</td>
#       <td>40:33</td>
#     </tr>
#     <tr>
#       <td>20</td>
#       <td>0.113214</td>
#       <td>0.118259</td>
#       <td>0.127632</td>
#       <td>40:34</td>
#     </tr>
#     <tr>
#       <td>21</td>
#       <td>0.112862</td>
#       <td>0.117998</td>
#       <td>0.127360</td>
#       <td>40:35</td>
#     </tr>
#     <tr>
#       <td>22</td>
#       <td>0.112772</td>
#       <td>0.117966</td>
#       <td>0.127352</td>
#       <td>40:36</td>
#     </tr>
#     <tr>
#       <td>23</td>
#       <td>0.113015</td>
#       <td>0.117819</td>
#       <td>0.127198</td>
#       <td>40:36</td>
#     </tr>
#     <tr>
#       <td>24</td>
#       <td>0.112682</td>
#       <td>0.117711</td>
#       <td>0.127076</td>
#       <td>40:37</td>
#     </tr>
#     <tr>
#       <td>25</td>
#       <td>0.112505</td>
#       <td>0.117652</td>
#       <td>0.127013</td>
#       <td>40:34</td>
#     </tr>
#     <tr>
#       <td>26</td>
#       <td>0.111515</td>
#       <td>0.117551</td>
#       <td>0.126904</td>
#       <td>40:34</td>
#     </tr>
#     <tr>
#       <td>27</td>
#       <td>0.111532</td>
#       <td>0.117444</td>
#       <td>0.126783</td>
#       <td>40:33</td>
#     </tr>
#     <tr>
#       <td>28</td>
#       <td>0.112565</td>
#       <td>0.117407</td>
#       <td>0.126746</td>
#       <td>40:30</td>
#     </tr>
#     <tr>
#       <td>29</td>
#       <td>0.111598</td>
#       <td>0.117365</td>
#       <td>0.126699</td>
#       <td>40:25</td>
#     </tr>
#     <tr>
#       <td>30</td>
#       <td>0.111979</td>
#       <td>0.117276</td>
#       <td>0.126606</td>
#       <td>40:29</td>
#     </tr>
#     <tr>
#       <td>31</td>
#       <td>0.112014</td>
#       <td>0.117165</td>
#       <td>0.126477</td>
#       <td>40:39</td>
#     </tr>
#     <tr>
#       <td>32</td>
#       <td>0.109629</td>
#       <td>0.117048</td>
#       <td>0.126343</td>
#       <td>40:40</td>
#     </tr>
#     <tr>
#       <td>33</td>
#       <td>0.112058</td>
#       <td>0.117020</td>
#       <td>0.126312</td>
#       <td>40:35</td>
#     </tr>
#   </tbody>
# </table><p>
#
#     <div>
#       <progress value='5115' class='' max='10252' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       49.89% [5115/10252 19:52&lt;19:57 0.1113]
#     </div>
# Better model found at epoch 0 with mae value: 0.16881751441260928.
# Better model found at epoch 1 with mae value: 0.14325424391357372.
# Better model found at epoch 2 with mae value: 0.13534550624484348.
# Better model found at epoch 3 with mae value: 0.13311183145923916.
# Better model found at epoch 4 with mae value: 0.13189776590962501.
# Better model found at epoch 5 with mae value: 0.13123424841454284.
# Better model found at epoch 6 with mae value: 0.13072279747152557.
# Better model found at epoch 7 with mae value: 0.13022355001329583.
# Better model found at epoch 8 with mae value: 0.1298754580975335.
# Better model found at epoch 9 with mae value: 0.12948720940868547.
# Better model found at epoch 10 with mae value: 0.12925001569268135.
# Better model found at epoch 11 with mae value: 0.1290863286314769.
# Better model found at epoch 12 with mae value: 0.12877721861121258.
# Better model found at epoch 13 with mae value: 0.12858958286239106.
# Better model found at epoch 14 with mae value: 0.12839662170682972.
# Better model found at epoch 15 with mae value: 0.12816652495626338.
# Better model found at epoch 16 with mae value: 0.12800061226836298.
# Better model found at epoch 17 with mae value: 0.12784576537924774.
# Better model found at epoch 18 with mae value: 0.1277218998627289.
# Better model found at epoch 19 with mae value: 0.12769185202122438.
# Better model found at epoch 20 with mae value: 0.12763245425499828.
# Better model found at epoch 21 with mae value: 0.12736033688426984.
# Better model found at epoch 22 with mae value: 0.1273521500456647.
# Better model found at epoch 23 with mae value: 0.12719762459784212.
# Better model found at epoch 24 with mae value: 0.12707562124977523.
# Better model found at epoch 25 with mae value: 0.12701343505077964.
# Better model found at epoch 26 with mae value: 0.12690448413302485.
# Better model found at epoch 27 with mae value: 0.12678313210686742.
# Better model found at epoch 28 with mae value: 0.12674580443849462.
# Better model found at epoch 29 with mae value: 0.1266994154472778.
# Better model found at epoch 30 with mae value: 0.12660560587322534.
# Better model found at epoch 31 with mae value: 0.12647677953915032.
# Better model found at epoch 32 with mae value: 0.12634347264021534.
# Better model found at epoch 33 with mae value: 0.12631157597615686.

# %%
res = dict()
for l in df_valid["L"].unique():
    ds_val = getattr(rnacomp.dataset, CFG.dataset_name)(df_valid.query("L==@l").copy(), mode='eval')
    ds_val_len = getattr(rnacomp.dataset, CFG.dataset_name)(df_valid.query("L==@l").copy(), mode='eval', mask_only=True)
    sampler_val = torch.utils.data.SequentialSampler(ds_val_len)
    len_sampler_val = LenMatchBatchSampler(sampler_val, batch_size=CFG.bs, 
                   drop_last=False)
    dl_val= DeviceDataLoader(torch.utils.data.DataLoader(ds_val, 
                   batch_sampler=len_sampler_val, num_workers=CFG.num_workers), CFG.device)

    data = DataLoaders(dl_val,dl_val)
    learn = Learner(data,
                    getattr(rnacomp.models, CFG.model_name)(dim = CFG.dim, graph_layers=CFG.graph_layers).cuda(), 
                    path = CFG.out, 
                    loss_func=loss_laplace,
                    metrics=[MAE()]).to_fp16() 
    learn.load('model')
    learn.eval()
    loss_, score_ = learn.validate()
    res[l]= score_

res = pd.DataFrame(pd.Series(res)).reset_index()
res.columns = ['L', 'mae']
res.sort_values(by="L")

# %%
res

# %%
res

# %%
# %load_ext autoreload
# %autoreload 2
import sys
sys.path.append('..')
import os
os.environ["CUDA_VISIBLE_DEVICES"]="1"

# %%
import rnacomp
import rnacomp.models
from rnacomp.fastai_fit import *
from rnacomp.dataset import LenMatchBatchSampler, DeviceDataLoader
from rnacomp.utils import seed_everything, MAE, loss_laplace
import gc
# Out:
# /opt/conda/lib/python3.10/site-packages/scipy/__init__.py:146: UserWarning: A NumPy version >=1.16.5 and <1.23.0 is required for this version of SciPy (detected version 1.23.5
#   warnings.warn(f"A NumPy version >={np_minversion} and <{np_maxversion}"

# %%
class CFG:
    path = Path("../data/")
    pathbb = Path("../data/Ribonanza_bpp_files")
    pathss = Path("../eda/train_ss_vienna_rna.parquet")
    split_id = Path('../eda/fold_split.csv')
    bs = 64
    num_workers = 12
    device = 'cuda'
    seed = 2023
    out = 'exp_09'
    dataset_name = 'RNA_DatasetBaselineSplitbppV0'
    sn_train = False
    
    model_name = 'RNA_ModelV7'
    dim = 192
    depth = 12
    dim_head = 32
   
    epoch = 64
    lr = 5e-4
    wd = 0.05
    pct_start = 0.02
    
seed_everything(CFG.seed)
os.makedirs(CFG.out, exist_ok=True)

# %%
fns = list(CFG.pathbb.rglob("*.txt"))
bpp_df = pd.DataFrame({"bpp": fns})
bpp_df['sequence_id'] = bpp_df['bpp'].apply(lambda x: x.stem)
bpp_df.drop_duplicates(subset = 'sequence_id', inplace=True)
df = pd.read_parquet(CFG.path/'train_data.parquet')
split = pd.read_csv(CFG.split_id)
df = pd.merge(df, split, on='sequence_id')
df = pd.merge(df, bpp_df, on='sequence_id')
#df = df.query("SN_filter==1").reset_index(drop=True)
df_train = df.query('is_train==True').reset_index(drop=True)
df_valid = df.query('is_train==False').reset_index(drop=True)


ds_train = getattr(rnacomp.dataset, CFG.dataset_name)(df_train, mode='train',sn_train=CFG.sn_train)
ds_train_len = getattr(rnacomp.dataset, CFG.dataset_name)(df_train, mode='train', mask_only=True,sn_train=CFG.sn_train)
sampler_train = torch.utils.data.RandomSampler(ds_train_len)
len_sampler_train = LenMatchBatchSampler(sampler_train, batch_size=CFG.bs,
            drop_last=True)
dl_train = DeviceDataLoader(torch.utils.data.DataLoader(ds_train, 
            batch_sampler=len_sampler_train, num_workers=CFG.num_workers,
            persistent_workers=True), CFG.device)


ds_val = getattr(rnacomp.dataset, CFG.dataset_name)(df_valid, mode='eval')
ds_val_len = getattr(rnacomp.dataset, CFG.dataset_name)(df_valid, mode='eval', mask_only=True)
sampler_val = torch.utils.data.SequentialSampler(ds_val_len)
len_sampler_val = LenMatchBatchSampler(sampler_val, batch_size=CFG.bs, 
               drop_last=False)
dl_val= DeviceDataLoader(torch.utils.data.DataLoader(ds_val, 
               batch_sampler=len_sampler_val, num_workers=CFG.num_workers), CFG.device)

data = DataLoaders(dl_train,dl_val)
gc.collect()
# Out:
# 16

# %%
learn = Learner(data,
                getattr(rnacomp.models, CFG.model_name)().cuda(), 
                path = CFG.out, 
                loss_func=loss_laplace,
                cbs=[GradientClip(3.0),
                    CSVLogger(),
                    SaveModelCallback(monitor='mae',comp=np.less,at_end=True)],
                metrics=[MAE()]).to_fp16() 
learn.fit_one_cycle(CFG.epoch, lr_max=CFG.lr, wd=CFG.wd, pct_start=CFG.pct_start)
# Out:
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     progress:not([value]), progress:not([value])::-webkit-progress-bar {
#         background: repeating-linear-gradient(45deg, #7e7e7e, #7e7e7e 10px, #5c5c5c 10px, #5c5c5c 20px);
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>
#     <div>
#       <progress value='62' class='' max='64' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       96.88% [62/64 19:30:51&lt;37:46]
#     </div>
#
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>mae</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>0.131070</td>
#       <td>0.156129</td>
#       <td>0.164014</td>
#       <td>18:33</td>
#     </tr>
#     <tr>
#       <td>1</td>
#       <td>0.124501</td>
#       <td>0.144300</td>
#       <td>0.152602</td>
#       <td>18:39</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>0.124013</td>
#       <td>0.138473</td>
#       <td>0.148762</td>
#       <td>18:45</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>0.122043</td>
#       <td>0.136128</td>
#       <td>0.146104</td>
#       <td>18:47</td>
#     </tr>
#     <tr>
#       <td>4</td>
#       <td>0.120246</td>
#       <td>0.135699</td>
#       <td>0.144942</td>
#       <td>18:48</td>
#     </tr>
#     <tr>
#       <td>5</td>
#       <td>0.120070</td>
#       <td>0.133254</td>
#       <td>0.143506</td>
#       <td>18:50</td>
#     </tr>
#     <tr>
#       <td>6</td>
#       <td>0.118701</td>
#       <td>0.135008</td>
#       <td>0.143265</td>
#       <td>18:47</td>
#     </tr>
#     <tr>
#       <td>7</td>
#       <td>0.118823</td>
#       <td>0.131571</td>
#       <td>0.141399</td>
#       <td>18:49</td>
#     </tr>
#     <tr>
#       <td>8</td>
#       <td>0.120384</td>
#       <td>0.131777</td>
#       <td>0.141323</td>
#       <td>18:51</td>
#     </tr>
#     <tr>
#       <td>9</td>
#       <td>0.118850</td>
#       <td>0.131883</td>
#       <td>0.140733</td>
#       <td>18:50</td>
#     </tr>
#     <tr>
#       <td>10</td>
#       <td>0.
td>
#     </tr>
#     <tr>
#       <td>57</td>
#       <td>0.110494</td>
#       <td>0.122317</td>
#       <td>0.131902</td>
#       <td>18:55</td>
#     </tr>
#     <tr>
#       <td>58</td>
#       <td>0.109034</td>
#       <td>0.1
# Better model found at epoch 0 with mae value: 0.16401353619169615.
# Better model found at epoch 1 with mae value: 0.15260194879204442.
# Better model found at epoch 2 with mae value: 0.14876169402357942.
# Better model found at epoch 3 with mae value: 0.14610409316505385.
# Better model found at epoch 4 with mae value: 0.14494247609422736.
# Better model found at epoch 5 with mae value: 0.14350633749658537.
# Better model found at epoch 6 with mae value: 0.14326545543936436.
# Better model found at epoch 7 with mae value: 0.14139862617151033.
# Better model found at epoch 8 with mae value: 0.14132345541149446.
# Better model found at epoch 9 with mae value: 0.1407329577295553.
# Better model found at epoch 10 with mae value: 0.13998041856153062.
# Better model found at epoch 11 with mae value: 0.13989996686420014.
# Better model found at epoch 12 with mae value: 0.1392996992749261.
# Better model found at epoch 13 with mae value: 0.139297594098006.
# Better model found at epoch 14 with mae value: 0.138391235466743.
# Better model found at epoch 17 with mae value: 0.13803189499367824.
# Better model found at epoch 20 with mae value: 0.13719163562236894.
# Better model found at epoch 21 with mae value: 0.1368340358832806.
# Better model found at epoch 24 with mae value: 0.1365402473151217.
# Better model found at epoch 26 with mae value: 0.136017184348608.
# Better model found at epoch 27 with mae value: 0.13596189176295362.
# Better model found at epoch 28 with mae value: 0.13558423885207246.
# Better model found at epoch 30 with mae value: 0.13554389857323462.
# Better model found at epoch 32 with mae value: 0.1351278512954338.
# Better model found at epoch 34 with mae value: 0.1346910376544162.
# Better model found at epoch 37 with mae value: 0.134063351534785.
# Better model found at epoch 40 with mae value: 0.1338125624468609.
# Better model found at epoch 41 with mae value: 0.13377737546598997.
# Better model found at epoch 42 with mae value: 0.13371353263340166.
# Better model found at epoch 43 with mae value: 0.13339697955108792.
# Better model found at epoch 44 with mae value: 0.13315569669366553.
# Better model found at epoch 45 with mae value: 0.13280094767066486.
# Better model found at epoch 48 with mae value: 0.13250409033842017.
# Better model found at epoch 50 with mae value: 0.13239821148470318.
# Better model found at epoch 51 with mae value: 0.13218796865920912.
# Better model found at epoch 53 with mae value: 0.1319464734500852.
# Better model found at epoch 57 with mae value: 0.13190166170973866.
# Better model found at epoch 58 with mae value: 0.1318967999865001.
# Better model found at epoch 59 with mae value: 0.131767281129285.
# Better model found at epoch 60 with mae value: 0.1316967429367085.

# %%
res = dict()
for l in df_valid["L"].unique():
    ds_val = getattr(rnacomp.dataset, CFG.dataset_name)(df_valid.query("L==@l").copy(), mode='eval')
    ds_val_len = getattr(rnacomp.dataset, CFG.dataset_name)(df_valid.query("L==@l").copy(), mode='eval', mask_only=True)
    sampler_val = torch.utils.data.SequentialSampler(ds_val_len)
    len_sampler_val = LenMatchBatchSampler(sampler_val, batch_size=CFG.bs, 
                   drop_last=False)
    dl_val= DeviceDataLoader(torch.utils.data.DataLoader(ds_val, 
                   batch_sampler=len_sampler_val, num_workers=CFG.num_workers), CFG.device)

    data = DataLoaders(dl_val,dl_val)
    learn = Learner(data,
                    getattr(rnacomp.models, CFG.model_name)().cuda(), 
                    path = CFG.out, 
                    loss_func=loss_laplace,
                    metrics=[MAE()]).to_fp16() 
    learn.load('model')
    learn.eval()
    loss_, score_ = learn.validate()
    res[l]= score_

res = pd.DataFrame(pd.Series(res)).reset_index()
res.columns = ['L', 'mae']
res.sort_values(by="L")

# %%
res

# %%
res
